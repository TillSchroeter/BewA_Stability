# %% [markdown]
# # Bibliotheken

# %%
### Bibliotheken
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### Daten einlesen probe

# Einlesen in einen DataFrame
df = pd.read_csv("C_Daten_Schröter_Till\Pre_C_Re_3.csv",delimiter=';',encoding='utf-8',decimal=',', skiprows=3)  # 👈 Wichtig: Komma als Dezimaltrennzeichen

### Daten extrahieren
# Zeitspalte
time = df["time"]  # Zeit in Sekunden
time = time - time[0]  # Zeit relativ zur ersten Zeit
# print(time)

### Gelenkswinkel-Spalten
# Gelenkwinkel – linkes Bein
lt_hip_flexion = df["LT Hip Flexion (deg)"]
lt_hip_abduction = df["LT Hip Abduction (deg)"]
lt_hip_rotation_ext = df["LT Hip Rotation Ext (deg)"]
lt_knee_abduction = df["LT Knee Abduction (deg)"]
lt_knee_rotation_ext = df["LT Knee Rotation Ext (deg)"]
lt_knee_flexion = df["LT Knee Flexion (deg)"]
lt_ankle_dorsiflexion = df["LT Ankle Dorsiflexion (deg)"]

# Gelenkwinkel – rechtes Bein
rt_hip_flexion = df["RT Hip Flexion (deg)"]
rt_hip_abduction = df["RT Hip Abduction (deg)"]
rt_hip_rotation_ext = df["RT Hip Rotation Ext (deg)"]
rt_knee_abduction = df["RT Knee Abduction (deg)"]
rt_knee_rotation_ext = df["RT Knee Rotation Ext (deg)"]
rt_knee_flexion = df["RT Knee Flexion (deg)"]
rt_ankle_dorsiflexion = df["RT Ankle Dorsiflexion (deg)"]
rt_ankle_abduction = df["RT Ankle Abduction (deg)"]
rt_ankle_inversion = df["RT Ankle Inversion (deg)"]


# Torso-Pelvis-Winkel
torso_pelvic_flexion_fwd = df["Torso-Pelvic Flexion Fwd (deg)"]

lt_torso_pelvic_flexion_lat = df["LT Torso-Pelvic Flexion Lat (deg)"]
rt_torso_pelvic_flexion_lat = df["RT Torso-Pelvic Flexion Lat (deg)"]

upper_spine_tilt_fwd = df["Noraxon MyoMotion-Segments-Upper spine-Tilt Fwd (deg)"]
upper_spine_roll = df["Noraxon MyoMotion-Segments-Upper spine-Roll (deg)"]
lt_upper_spine_tilt_lat = df["Noraxon MyoMotion-Segments-Upper spine-LT Tilt Lat (deg)"]
rt_upper_spine_tilt_lat = df["Noraxon MyoMotion-Segments-Upper spine-RT Tilt Lat (deg)"]
lt_upper_spine_rotation = df["Noraxon MyoMotion-Segments-Upper spine-LT Rotation (deg)"]
rt_upper_spine_rotation = df["Noraxon MyoMotion-Segments-Upper spine-RT Rotation (deg)"]

###########################################################################################################################################################
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\tills\AppData\Local\Temp\ipykernel_29528\1003926560.py:4: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv("C_Daten_Schröter_Till\Pre_C_Re_3.csv",delimiter=';',encoding='utf-8',decimal=',', skiprows=3)  # 👈 Wichtig: Komma als Dezimaltrennzeichen
# C:\Users\tills\AppData\Local\Temp\ipykernel_29528\1003926560.py:4: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C_Daten_Schröter_Till\Pre_C_Re_3.csv",delimiter=';',encoding='utf-8',decimal=',', skiprows=3)  # 👈 Wichtig: Komma als Dezimaltrennzeichen

# %% [markdown]
# # Ausprobieren

# %%
### Plottten
# Subplots: 3 Zeilen (Hip, Knee, Ankle), 2 Spalten (LT, RT)
fig, axes = plt.subplots(5, 2, figsize=(20, 16))
fig.suptitle("Gelenkwinkel über der Zeit (Sprung mit rechten bein)", fontsize=16)

# Hip Flexion
axes[0, 0].plot(time, lt_hip_flexion, label="LT Hip Flexion", color="blue")
axes[0, 0].set_ylabel("Hip (deg)")
axes[0, 0].legend()

axes[0, 1].plot(time, rt_hip_flexion, label="RT Hip Flexion", color="red")
axes[0, 1].set_ylabel("Hip (deg)")
axes[0, 1].legend()

# Knee Flexion
axes[1, 0].plot(time, lt_knee_flexion, label="LT Knee Flexion", color="blue")
axes[1, 0].set_ylabel("Knee (deg)")
axes[1, 0].legend()

axes[1, 1].plot(time, rt_knee_flexion, label="RT Knee Flexion", color="red")
axes[1, 1].set_ylabel("Knee (deg)")
axes[1, 1].legend()
# Ankle Dorsiflexion
axes[2, 0].plot(time, lt_ankle_dorsiflexion, label="LT Ankle Dorsiflexion", color="blue")
axes[2, 0].set_ylabel("Ankle (deg)")
axes[2, 0].set_xlabel("Time (s)")
axes[2, 0].legend()

axes[2, 1].plot(time, rt_ankle_dorsiflexion, label="RT Ankle Dorsiflexion", color="red")
axes[2, 1].set_ylabel("Ankle (deg)")
axes[2, 1].legend()

# lt_torso_pelvic_flexion_lat
axes[3, 0].plot(time, lt_torso_pelvic_flexion_lat, label="LT Torso-Pelvic Flexion Lat", color="blue")
axes[3, 0].set_ylabel("Torso-Pelvis (deg)")
axes[3, 0].legend()

axes[3, 1].plot(time, rt_torso_pelvic_flexion_lat, label="RT Torso-Pelvic Flexion Lat", color="red")
axes[3, 1].set_ylabel("Torso-Pelvis (deg)")
axes[3, 1].legend()

# lt_knee_rotation_ext
axes[4, 0].plot(time, rt_knee_rotation_ext, label="LT Knee Rotation Ext", color="blue")
axes[4, 0].set_ylabel("Knee (deg)")
axes[4, 0].set_xlabel("Time (s)")
axes[4, 0].legend()

axes[4, 1].plot(time, rt_knee_abduction, label="RT Knee Rotation Ext", color="red")
axes[4, 1].set_ylabel("Knee (deg)")
axes[4, 1].set_xlabel("Time (s)")
axes[4, 1].legend()



# plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Platz für den Titel lassen
plt.show()

# Pelvis Flexion
plt.figure(figsize=(10, 4))
plt.plot(time, torso_pelvic_flexion_fwd, label="Pelvis Flexion", color="green")
plt.title("Pelvis Flexion über der Zeit")
plt.xlabel("Time (s)")
plt.ylabel("Pelvis Flexion (deg)")
plt.legend()
plt.tight_layout()
plt.show()

# Upper_Spine_Tilt
plt.figure(figsize=(10, 4))
plt.plot(time, upper_spine_tilt_fwd, label="Upper Spine Tilt", color="purple")
plt.title("Upper Spine Tilt fwd über der Zeit")
plt.xlabel("Time (s)")
plt.ylabel("Upper Spine Tilt (deg)")
plt.legend()
plt.tight_layout()
plt.show()


#Upper_Spine_Roll
plt.figure(figsize=(10, 4))
plt.plot(time, upper_spine_roll, label="Upper Spine Roll", color="orange")
plt.title("Upper Spine Roll über der Zeit")
plt.xlabel("Time (s)")
plt.ylabel("Upper Spine Roll (deg)")
plt.legend()
plt.tight_layout()
plt.show()

#lt_Upper_Spine_Tilt
plt.figure(figsize=(10, 4))
plt.plot(time, lt_upper_spine_tilt_lat, label="LT Upper Spine Tilt", color="blue")
plt.title("LT Upper Spine Tilt über der Zeit")
plt.xlabel("Time (s)")
plt.ylabel("LT Upper Spine Tilt (deg)")
plt.legend()
plt.tight_layout()
plt.show()

#rt_upper_spine_tilt_lat
plt.figure(figsize=(10, 4))
plt.plot(time, rt_upper_spine_tilt_lat, label="RT Upper Spine Tilt", color="green")
plt.title("RT Upper Spine Tilt über der Zeit")
plt.xlabel("Time (s)")
plt.ylabel("RT Upper Spine Tilt (deg)")
plt.legend()
plt.tight_layout()
plt.show()


#lt_Upper_Spine_Rotation
plt.figure(figsize=(10, 4))
plt.plot(time, lt_upper_spine_rotation, label="LT Upper Spine Rotation", color="red")
plt.title("LT Upper Spine Rotation über der Zeit")
plt.xlabel("Time (s)")
plt.ylabel("LT Upper Spine Rotation (deg)")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Datei Struktur

# %%
### Daten strukturiert einlesen

# Manuelle Datei-Zuordnung (Dateiname → Key)
C_Daten_file_map = {
    "Li_1_Pre": "C_Daten_Schröter_Till/Pre_C_Li_1.csv",
    "Li_2_Pre": "C_Daten_Schröter_Till/Pre_C_Li_2.csv",
    "Li_3_Pre": "C_Daten_Schröter_Till/Pre_C_Li_3.csv",
    "Re_1_Pre": "C_Daten_Schröter_Till/Pre_C_Re_1.csv",
    "Re_2_Pre": "C_Daten_Schröter_Till/Pre_C_Re_2.csv",
    "Re_3_Pre": "C_Daten_Schröter_Till/Pre_C_Re_3.csv",
    "Li_1_Post": "C_Daten_Schröter_Till/Post_C_Li_1.csv",
    "Li_2_Post": "C_Daten_Schröter_Till/Post_C_Li_2.csv",
    "Li_3_Post": "C_Daten_Schröter_Till/Post_C_Li_3.csv",
    "Re_1_Post": "C_Daten_Schröter_Till/Post_C_Re_1.csv",
    "Re_2_Post": "C_Daten_Schröter_Till/Post_C_Re_2.csv",
    "Re_3_Post": "C_Daten_Schröter_Till/Post_C_Re_3.csv",
}

landing_peaks = {
    "Li_1_Pre": 3.241,
    "Li_2_Pre": 2.769,
    "Li_3_Pre": 3.545,
    "Re_1_Pre": 3.418,
    "Re_2_Pre": 3.223,
    "Re_3_Pre": 2.963,
    "Li_1_Post": 3.719,
    "Li_2_Post": 2.865,
    "Li_3_Post": 3.565,
    "Re_1_Post": 3.038,
    "Re_2_Post": 2.977,
    "Re_3_Post": 3.124,
}

# Relevante Spalten
columns_to_extract = [
    # Zeit
    "time",

    # Linkes Bein
    "LT Hip Flexion (deg)", 
    "LT Hip Abduction (deg)", 
    "LT Hip Rotation Ext (deg)",
    "LT Knee Abduction (deg)", 
    "LT Knee Rotation Ext (deg)", 
    "LT Knee Flexion (deg)",
    "LT Ankle Dorsiflexion (deg)",
    "LT Ankle Abduction (deg)",
    "LT Ankle Inversion (deg)",

    # Rechtes Bein
    "RT Hip Flexion (deg)", 
    "RT Hip Abduction (deg)", 
    "RT Hip Rotation Ext (deg)",
    "RT Knee Abduction (deg)", 
    "RT Knee Rotation Ext (deg)", 
    "RT Knee Flexion (deg)",
    "RT Ankle Dorsiflexion (deg)",
    "RT Ankle Abduction (deg)",
    "RT Ankle Inversion (deg)",

    # Torso-Pelvis
    "Torso-Pelvic Flexion Fwd (deg)", "LT Torso-Pelvic Flexion Lat (deg)", "RT Torso-Pelvic Flexion Lat (deg)",

    # Upper spine
    "Noraxon MyoMotion-Segments-Upper spine-Tilt Fwd (deg)",
    #"Noraxon MyoMotion-Segments-Upper spine-Roll (deg)"            # --> gibts nicht in allen CSVs 
    "Noraxon MyoMotion-Segments-Upper spine-LT Tilt Lat (deg)",
    "Noraxon MyoMotion-Segments-Upper spine-RT Tilt Lat (deg)",
    "Noraxon MyoMotion-Segments-Upper spine-LT Rotation (deg)",
    "Noraxon MyoMotion-Segments-Upper spine-RT Rotation (deg)"
]

# haupt Datenstruktur initialisieren
data = {}

for key, filepath in C_Daten_file_map.items():
    df = pd.read_csv(filepath, delimiter=';', encoding='utf-8', decimal=',', skiprows=3)
    df["time"] = df["time"] - df["time"].iloc[0]

    # Peak-Zeit ermitteln
    peak_time = landing_peaks[key]
    cutoff_time = peak_time + 3.0

    # Filter anwenden: alle Zeilen bis 3 Sekunden nach Peak
    df = df[df["time"] <= cutoff_time].reset_index(drop=True)

    # Relevante Spalten auswählen
    df_selected = df[columns_to_extract].copy()

    # In Datenstruktur speichern
    data[key] = {
        "df": df_selected,
        "landing_peak_time": peak_time
    }
# Out:
# C:\Users\tills\AppData\Local\Temp\ipykernel_29528\1589244528.py:77: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, delimiter=';', encoding='utf-8', decimal=',', skiprows=3)
# C:\Users\tills\AppData\Local\Temp\ipykernel_29528\1589244528.py:77: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, delimiter=';', encoding='utf-8', decimal=',', skiprows=3)
# C:\Users\tills\AppData\Local\Temp\ipykernel_29528\1589244528.py:77: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, delimiter=';', encoding='utf-8', decimal=',', skiprows=3)
# C:\Users\tills\AppData\Local\Temp\ipykernel_29528\1589244528.py:77: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, delimiter=';', encoding='utf-8', decimal=',', skiprows=3)
# C:\Users\tills\AppData\Local\Temp\ipykernel_29528\1589244528.py:77: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, delimiter=';', encoding='utf-8', decimal=',', skiprows=3)
# C:\Users\tills\AppData\Local\Temp\ipykernel_29528\1589244528.py:77: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, delimiter=';', encoding='utf-8', decimal=',', skiprows=3)
# C:\Users\tills\AppData\Local\Temp\ipykernel_29528\1589244528.py:77: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, delimiter=';', encoding='utf-8', decimal=',', skiprows=3)
# C:\Users\tills\AppData\Local\Temp\ipykernel_29528\1589244528.py:77: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, delimiter=';', encoding='utf-8', decimal=',', skiprows=3)
# C:\Users\tills\AppData\Local\Temp\ipykernel_29528\1589244528.py:77: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, delimiter=';', encoding='utf-8', decimal=',', skiprows=3)
# C:\Users\tills\AppData\Local\Temp\ipykernel_29528\1589244528.py:77: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, delimiter=';', encoding='utf-8', decimal=',', skiprows=3)
# C:\Users\tills\AppData\Local\Temp\ipykernel_29528\1589244528.py:77: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, delimiter=';', encoding='utf-8', decimal=',', skiprows=3)
# C:\Users\tills\AppData\Local\Temp\ipykernel_29528\1589244528.py:77: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, delimiter=';', encoding='utf-8', decimal=',', skiprows=3)

# %% [markdown]
# ## Plot Parameter

# %%
keys = ("Li_1_Pre", "Li_2_Pre", "Li_3_Pre","Re_1_Pre","Re_2_Pre","Re_3_Pre", "Li_1_Post", "Li_2_Post", "Li_3_Post","Re_1_Post","Re_2_Post","Re_3_Post")

def get_keys_and_direction(seite: str, phase: str):
    if seite not in ("LT", "RT"):
        raise ValueError("Seite muss 'LT' oder 'RT' sein.")
    if phase not in ("Pre", "Post"):
        raise ValueError("Phase muss 'Pre' oder 'Post' sein.")

    keys_map = {
        ("RT", "Pre"): ["Re_1_Pre", "Re_2_Pre", "Re_3_Pre"],
        ("LT", "Pre"): ["Li_1_Pre", "Li_2_Pre", "Li_3_Pre"],
        ("RT", "Post"): ["Re_1_Post", "Re_2_Post", "Re_3_Post"],
        ("LT", "Post"): ["Li_1_Post", "Li_2_Post", "Li_3_Post"]
    }

    keys = keys_map[(seite, phase)]
    direction = seite  # 'RT' oder 'LT'

    return keys, direction


### Hier eingeben, welche Seite und Phase geplottet werden sollen
keys_plotting, direktion = get_keys_and_direction("RT", "Pre")

### Farben für die Plots definieren
colors = ['blue', 'red', 'green']
color_peak = 'black'
color_stable = 'grey'

# %% [markdown]
# # Erste Stabilisationsphase
# (Knie, Hüft, Sprunggelenkswinkel verändern sich nicht mehr viel nach landung)

# %%
### Funktion zur Bestimmung des stabilen Zeitpunkts
def find_stable_time(time, signal, peak_time, slope_threshold, min_consecutive):
    """
    Gibt den ersten Zeitpunkt zurück, ab dem die Steigung für `min_consecutive` Punkte
    in Folge unterhalb `slope_threshold` bleibt.
    """
    # Nur Daten nach dem Peak betrachten
    mask = time > peak_time
    time_post = time[mask].reset_index(drop=True)
    signal_post = signal[mask].reset_index(drop=True)

    if len(time_post) < min_consecutive:
        return np.nan

    # Steigungen berechnen
    slopes = np.gradient(signal_post, time_post)
    is_stable = np.abs(slopes) < slope_threshold

    # Finde erste Phase mit `min_consecutive` stabilen Werten
    count = 0
    for i in range(len(is_stable)):
        if is_stable[i]:
            count += 1
            if count >= min_consecutive:
                # Index am Anfang des stabilen Fensters
                window_start_index = i - min_consecutive + 1
                return time_post[window_start_index]
        else:
            count = 0

    return np.nan

    
### Bestimmungs parameter
RT_joints = ("RT Knee Flexion (deg)", "RT Hip Flexion (deg)", "RT Ankle Dorsiflexion (deg)")
LT_joints = ("LT Knee Flexion (deg)", "LT Hip Flexion (deg)", "LT Ankle Dorsiflexion (deg)")
# pre_treshholds = (9.75, 9.75, 9.75)  # Schwellenwerte durch probieren
# post_treshholds = (10.76, 10.75, 10.76)
pre_treshholds = (9.5, 9.75, 10.75)  # Schwellenwerte durch probieren
post_treshholds = (9.5, 10.75, 10.75)
mean_stable_times = {}

for key in keys:
    stable_times = []

    # Entscheide, ob linke oder rechte Gelenke verwendet werden sollen und Pre oder Post
    if key.startswith("R"):
        joints = RT_joints

        if key[6] == "r":               # r für Pre
            min_consecutive = 900
            treshholds = pre_treshholds
        elif key[6] == "o":             # o für Post
            min_consecutive = 500
            treshholds = post_treshholds

    elif key.startswith("L"):
        joints = LT_joints

        if key[6] == "r":               # r für Pre
            min_consecutive = 900
            treshholds = pre_treshholds
        elif key[6] == "o":             # o für Post  
            min_consecutive = 500
            treshholds = post_treshholds


    for joint, th in zip(joints, treshholds):
        flexion = data[key]["df"][joint]
        time = data[key]["df"]["time"]
        peak_time = data[key]["landing_peak_time"]
        slope_threshold = th

        stable_time = find_stable_time(time, flexion, peak_time, slope_threshold, min_consecutive)
        stable_times.append(stable_time)

        print(f"Stabiler Zeitpunkt für {key} ({joint}): {stable_time:.3f} s")

    # Mittelwert der drei Zeitpunkte (sofern keine NaNs enthalten)
    stable_times = [t for t in stable_times if not np.isnan(t)]
    if stable_times:
        mean_time = np.mean(stable_times)
    else:
        mean_time = np.nan

    mean_stable_times[key] = mean_time
    print(f"🟢 Mittlerer stabiler Zeitpunkt für {key}: {mean_time:.3f} s\n")


### in Datenstruktur speichern
for key in mean_stable_times:
    data[key]["stable_time"] = mean_stable_times[key]
# Out:
# Stabiler Zeitpunkt für Li_1_Pre (LT Knee Flexion (deg)): 4.931 s
# Stabiler Zeitpunkt für Li_1_Pre (LT Hip Flexion (deg)): 4.971 s
# Stabiler Zeitpunkt für Li_1_Pre (LT Ankle Dorsiflexion (deg)): 4.642 s
# 🟢 Mittlerer stabiler Zeitpunkt für Li_1_Pre: 4.848 s
#
# Stabiler Zeitpunkt für Li_2_Pre (LT Knee Flexion (deg)): 4.368 s
# Stabiler Zeitpunkt für Li_2_Pre (LT Hip Flexion (deg)): 4.407 s
# Stabiler Zeitpunkt für Li_2_Pre (LT Ankle Dorsiflexion (deg)): 4.117 s
# 🟢 Mittlerer stabiler Zeitpunkt für Li_2_Pre: 4.297 s
#
# Stabiler Zeitpunkt für Li_3_Pre (LT Knee Flexion (deg)): 5.121 s
# Stabiler Zeitpunkt für Li_3_Pre (LT Hip Flexion (deg)): 5.160 s
# Stabiler Zeitpunkt für Li_3_Pre (LT Ankle Dorsiflexion (deg)): 4.970 s
# 🟢 Mittlerer stabiler Zeitpunkt für Li_3_Pre: 5.084 s
#
# Stabiler Zeitpunkt für Re_1_Pre (RT Knee Flexion (deg)): 5.297 s
# Stabiler Zeitpunkt für Re_1_Pre (RT Hip Flexion (deg)): 4.663 s
# Stabiler Zeitpunkt für Re_1_Pre (RT Ankle Dorsiflexion (deg)): 4.582 s
# 🟢 Mittlerer stabiler Zeitpunkt für Re_1_Pre: 4.847 s
#
# Stabiler Zeitpunkt für Re_2_Pre (RT Knee Flexion (deg)): 4.775 s
# Stabiler Zeitpunkt für Re_2_Pre (RT Hip Flexion (deg)): 4.575 s
# Stabiler Zeitpunkt für Re_2_Pre (RT Ankle Dorsiflexion (deg)): 4.459 s
# 🟢 Mittlerer stabiler Zeitpunkt für Re_2_Pre: 4.603 s
#
# Stabiler Zeitpunkt für Re_3_Pre (RT Knee Flexion (deg)): nan s
# Stabiler Zeitpunkt für Re_3_Pre (RT Hip Flexion (deg)): 4.562 s
# Stabiler Zeitpunkt für Re_3_Pre (RT Ankle Dorsiflexion (deg)): 4.087 s
# 🟢 Mittlerer stabiler Zeitpunkt für Re_3_Pre: 4.325 s
#
# Stabiler Zeitpunkt für Li_1_Post (LT Knee Flexion (deg)): 5.304 s
# Stabiler Zeitpunkt für Li_1_Post (LT Hip Flexion (deg)): 5.593 s
# Stabiler Zeitpunkt für Li_1_Post (LT Ankle Dorsiflexion (deg)): nan s
# 🟢 Mittlerer stabiler Zeitpunkt für Li_1_Post: 5.448 s
#
# Stabiler Zeitpunkt für Li_2_Post (LT Knee Flexion (deg)): 4.300 s
# Stabiler Zeitpunkt für Li_2_Post (LT Hip Flexion (deg)): 4.435 s
# Stabiler Zeitpunkt für Li_2_Post (LT Ankle Dorsiflexion (deg)): nan s
# 🟢 Mittlerer stabiler Zeitpunkt für Li_2_Post: 4.367 s
#
# Stabiler Zeitpunkt für Li_3_Post (LT Knee Flexion (deg)): 5.039 s
# Stabiler Zeitpunkt für Li_3_Post (LT Hip Flexion (deg)): 5.098 s
# Stabiler Zeitpunkt für Li_3_Post (LT Ankle Dorsiflexion (deg)): 4.779 s
# 🟢 Mittlerer stabiler Zeitpunkt für Li_3_Post: 4.972 s
#
# Stabiler Zeitpunkt für Re_1_Post (RT Knee Flexion (deg)): 4.585 s
# Stabiler Zeitpunkt für Re_1_Post (RT Hip Flexion (deg)): 4.659 s
# Stabiler Zeitpunkt für Re_1_Post (RT Ankle Dorsiflexion (deg)): 4.535 s
# 🟢 Mittlerer stabiler Zeitpunkt für Re_1_Post: 4.593 s
#
# Stabiler Zeitpunkt für Re_2_Post (RT Knee Flexion (deg)): nan s
# Stabiler Zeitpunkt für Re_2_Post (RT Hip Flexion (deg)): nan s
# Stabiler Zeitpunkt für Re_2_Post (RT Ankle Dorsiflexion (deg)): 4.339 s
# 🟢 Mittlerer stabiler Zeitpunkt für Re_2_Post: 4.339 s
#
# Stabiler Zeitpunkt für Re_3_Post (RT Knee Flexion (deg)): 4.693 s
# Stabiler Zeitpunkt für Re_3_Post (RT Hip Flexion (deg)): 4.458 s
# Stabiler Zeitpunkt für Re_3_Post (RT Ankle Dorsiflexion (deg)): 4.658 s
# 🟢 Mittlerer stabiler Zeitpunkt für Re_3_Post: 4.603 s

# %%
### Probieren ###

key11 = "Li_1_Post" 

knee_flexion, time, peak_time = data[key11]["df"]["LT Knee Flexion (deg)"], data[key11]["df"]["time"], data[key11]["landing_peak_time"]
hip_flexion, time, peak_time = data[key11]["df"]["LT Hip Flexion (deg)"], data[key11]["df"]["time"], data[key11]["landing_peak_time"]
ankle_flexion, time, peak_time = data[key11]["df"]["LT Ankle Dorsiflexion (deg)"], data[key11]["df"]["time"], data[key11]["landing_peak_time"]

stable_time = find_stable_time(time, ankle_flexion, peak_time, slope_threshold=10.75, min_consecutive=500)
print(f"Stabiler Zeitpunkt für {key11}: {stable_time:.3f} s")

# Plotten
plt.figure(figsize=(10,5))
plt.plot(time, ankle_flexion, label="Knie-Flexion")
plt.axvline(x=peak_time, color='red', linestyle='--', label="Landing Peak")
if not np.isnan(stable_time):
    plt.axvline(x=stable_time, color='green', linestyle='--', label="Stabiler Zeitpunkt")
plt.xlabel("Zeit (s)")
plt.ylabel("Knie-Flexion (°)")
plt.title(f"Knie-Flexion und stabiler Zeitpunkt für {key11}")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Stabiler Zeitpunkt für Li_1_Post: nan s

# %% [markdown]
# # Stabilisierungszeit auswerten

# %%
# Differenz zwischen peak time und stable time

# for key in keys:
#     peak_time = data[key]["landing_peak_time"]
#     stable_time = data[key]["stable_time"]

#     time_difference = stable_time - peak_time
#     # Hier kannst du die Zeitdifferenz speichern oder weiterverarbeiten
#     data[key]["time_difference"] = time_difference
#     print(f"Zeitdifferenz für {key}: {time_difference:.3f} s")

last_phase = None  # Merken, ob vorher "Pre" oder "Post" war

for key in keys:
    # Teile Key auf → z. B. "Re_1_Pre" → ["Re", "1", "Pre"]
    parts = key.split("_")
    phase = parts[2]  # "Pre" oder "Post"

    # Trennlinie bei Wechsel von Pre → Post
    if last_phase is not None and phase != last_phase:
        print("-------------------------------------")

    peak_time = data[key]["landing_peak_time"]
    stable_time = data[key]["stable_time"]
    time_difference = stable_time - peak_time

    data[key]["time_difference"] = time_difference
    print(f"Zeitdifferenz für {key}: {time_difference:.3f} s")

    last_phase = phase
# Out:
# Zeitdifferenz für Li_1_Pre: 1.607 s
# Zeitdifferenz für Li_2_Pre: 1.528 s
# Zeitdifferenz für Li_3_Pre: 1.539 s
# Zeitdifferenz für Re_1_Pre: 1.429 s
# Zeitdifferenz für Re_2_Pre: 1.380 s
# Zeitdifferenz für Re_3_Pre: 1.362 s
# -------------------------------------
# Zeitdifferenz für Li_1_Post: 1.729 s
# Zeitdifferenz für Li_2_Post: 1.502 s
# Zeitdifferenz für Li_3_Post: 1.407 s
# Zeitdifferenz für Re_1_Post: 1.555 s
# Zeitdifferenz für Re_2_Post: 1.362 s
# Zeitdifferenz für Re_3_Post: 1.479 s

# %%
### Funktion für Boxplots
def plot_boxplot(title, y_label, data_key):
    # Liste für DataFrame-Zeilen
    rows = []

    for key, values in data.items():
        if data_key in values and not np.isnan(values[data_key]):
            side = "Li" if key.startswith("Li") else "Re"
            phase = "Pre" if "Pre" in key else "Post"
            rows.append({
                "key": key,
                "side": side,
                "phase": phase,
                data_key: values[data_key]
            })

    df_plot = pd.DataFrame(rows)

    plt.figure(figsize=(6, 4))
    sns.boxplot(data=df_plot[df_plot["phase"] == "Pre"], x="side", y=data_key)
    plt.title(title + "Links vs. Rechts (Pre)")
    plt.ylabel(y_label)
    plt.xlabel("Bein")
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.savefig("Plot_Bilder_IMU/" + data_key + "zeitdifferenz_pre_link_rechts.png", dpi=300)
    plt.show()

    plt.figure(figsize=(6, 4))
    sns.boxplot(data=df_plot[df_plot["phase"] == "Post"], x="side", y=data_key)
    plt.title(title + "Links vs. Rechts (Post)")
    plt.ylabel(y_label)
    plt.xlabel("Bein")
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.savefig("Plot_Bilder_IMU/" + data_key + "zeitdifferenz_post_link_rechts.png", dpi=300)
    plt.show()

    plt.figure(figsize=(8, 5))
    sns.boxplot(data=df_plot, x="phase", y=data_key, hue="side")
    plt.title(title + "Pre vs. Post (Links & Rechts)")
    plt.ylabel(y_label)
    plt.xlabel("Phase")
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.legend(title="Bein")
    plt.tight_layout()
    plt.savefig("Plot_Bilder_IMU/" + data_key + "zeitdifferenz_pre_post_link&rechts.png", dpi=300)
    plt.show()

# %% [markdown]
# ## Vergleich

# %%
### Plotten der Zeitdifferenzen Rechts und Links und Pre und Post
plot_boxplot (
    title="Zeitdifferenz Landing & stable Time: ",
    y_label="Zeitdifferenz (s)",
    data_key="time_difference"
)

# %% [markdown]
# # Knie Auswertung

# %%
print (data["Re_1_Pre"]["stable_time"])
print (data["Re_1_Pre"]["df"]["LT Hip Flexion (deg)"])
# Out:
# 4.847333333333334
# 0       -6.552090
# 1       -6.565849
# 2       -6.579608
# 3       -6.589236
# 4       -6.598865
#           ...
# 6414    15.172077
# 6415    15.172601
# 6416    15.173125
# 6417    15.173649
# 6418    15.174161
# Name: LT Hip Flexion (deg), Length: 6419, dtype: float64

# %%
### Hüfte Flexion
# Erstelle Subplots (1 Zeile, 3 Spalten)
fig1, axes1 = plt.subplots(1, 3, figsize=(16, 4), sharey=True)

for i, (key, color) in enumerate(zip(keys_plotting, colors)):
    df = data[key]["df"]
    time = df["time"]
    df_angle = df[direktion + " Hip Flexion (deg)"]
    peak_time = data[key]["landing_peak_time"]
    stable_time = data[key]["stable_time"]

    ax = axes1[i]
    ax.plot(time, df_angle, color=color)
    ax.axvline(x=peak_time, color=color_peak, linestyle='--', label='Landing Peak')
    ax.axvline(x=stable_time, color=color_stable, linestyle='--', label='stable time')
    ax.set_title(key)
    ax.set_xlabel("Zeit (s)")
    if i == 0:
        ax.set_ylabel("Hüft-Flexion (°)")
    ax.grid(True)
    ax.legend()

# Abstand optimieren
plt.tight_layout()
plt.suptitle(direktion + " Hüftgelenk - Flexion", fontsize=14, y=1.05)
plt.savefig("Plot_Bilder_IMU/hüftgelenk_flexion.png", dpi=300)
plt.show()


### Kniegelenk Flexion
# Erstelle Subplots (1 Zeile, 3 Spalten)
fig1, axes1 = plt.subplots(1, 3, figsize=(16, 4), sharey=True)

for i, (key, color) in enumerate(zip(keys_plotting, colors)):
    df = data[key]["df"]
    time = df["time"]
    df_angle = df[direktion + " Knee Flexion (deg)"]
    peak_time = data[key]["landing_peak_time"]
    stable_time = data[key]["stable_time"]

    ax = axes1[i]
    ax.plot(time, df_angle, color=color)
    ax.axvline(x=peak_time, color=color_peak, linestyle='--', label='Landing Peak')
    ax.axvline(x=stable_time, color=color_stable, linestyle='--', label='stable time')
    ax.set_title(key)
    ax.set_xlabel("Zeit (s)")
    if i == 0:
        ax.set_ylabel("Knie-Flexion (°)")
    ax.grid(True)
    ax.legend()

# Abstand optimieren
plt.tight_layout()
plt.suptitle(direktion + " Kniegelenk - Flexion", fontsize=14, y=1.05)
plt.savefig("Plot_Bilder_IMU/kniegelenk_flexion.png", dpi=300)
plt.show()

### Kniegelenk Abduktion
# Erstelle Subplots (1 Zeile, 3 Spalten)
fig2, axes2 = plt.subplots(1, 3, figsize=(16, 4), sharey=True)

for i, (key, color) in enumerate(zip(keys_plotting, colors)):
    df = data[key]["df"]
    time = df["time"]
    df_angle = df[direktion + " Knee Abduction (deg)"]
    peak_time = data[key]["landing_peak_time"]
    stable_time = data[key]["stable_time"]

    ax = axes2[i]
    ax.plot(time, df_angle, color=color)
    ax.axvline(x=peak_time, color=color_peak, linestyle='--', label='Landing Peak')
    ax.axvline(x=stable_time, color=color_stable, linestyle='--', label='stable time')
    ax.set_title(key)
    ax.set_xlabel("Zeit (s)")
    if i == 0:
        ax.set_ylabel("Knie-Abduction (°)")
    ax.grid(True)
    ax.legend()

# Abstand optimieren
plt.tight_layout()
plt.suptitle(direktion + " Kniegelenk - Abduction", fontsize=14, y=1.05)
plt.show()

### Kniegelenk Rotation
# Erstelle Subplots (1 Zeile, 3 Spalten)
fig3, axes3 = plt.subplots(1, 3, figsize=(16, 4), sharey=True)

for i, (key, color) in enumerate(zip(keys_plotting, colors)):
    df = data[key]["df"]
    time = df["time"]
    df_angle = df[direktion + " Knee Rotation Ext (deg)"]
    peak_time = data[key]["landing_peak_time"]
    stable_time = data[key]["stable_time"]

    ax = axes3[i]
    ax.plot(time, df_angle, color=color)
    ax.axvline(x=peak_time, color=color_peak, linestyle='--', label='Landing Peak')
    ax.axvline(x=stable_time, color=color_stable, linestyle='--', label='stable time')
    ax.set_title(key)
    ax.set_xlabel("Zeit (s)")
    if i == 0:
        ax.set_ylabel("Knie-Rotation (°)")
    ax.grid(True)
    ax.legend()

# Abstand optimieren
plt.tight_layout()
plt.suptitle(direktion + " Kniegelenk - Rotation", fontsize=14, y=1.05)
plt.show()

# %% [markdown]
# # Ankle Auswerung

# %%
### Plotten vom Ankle

# Ankel Dorsiflexion
fig1, axes1 = plt.subplots(1, 3, figsize=(15, 4), sharey=True)

for i, (key, color) in enumerate(zip(keys_plotting, colors)):
    df = data[key]["df"]
    
    time = df["time"]
    df_angle = df[direktion + " Ankle Dorsiflexion (deg)"]
    peak_time = data[key]["landing_peak_time"]
    stable_time = data[key]["stable_time"]

    ax = axes1[i]
    ax.plot(time, df_angle, color=color)
    ax.axvline(x=peak_time, color=color_peak, linestyle='--', label='Landing Peak')
    ax.axvline(x=stable_time, color=color_stable, linestyle='--', label='stable time')
    ax.set_title(key)
    ax.set_xlabel("Zeit (s)")
    if i == 0:
        ax.set_ylabel("Ankle Dorsiflexion (°)")
    ax.grid(True)
    ax.legend()

# Abstand optimieren
plt.tight_layout()
plt.suptitle(direktion + " Sprunggelenk - Dorsiflexion bei Pre-Rechts Messungen", fontsize=14, y=1.05)
plt.savefig("Plot_Bilder_IMU/sprunggelenk_dorsiflexion.png", dpi=300)
plt.show()

# Ankle Abduction
fig1, axes1 = plt.subplots(1, 3, figsize=(15, 4), sharey=True)

for i, (key, color) in enumerate(zip(keys_plotting, colors)):
    df = data[key]["df"]
    time = df["time"]
    df_angle = df[direktion + " Ankle Abduction (deg)"]
    peak_time = data[key]["landing_peak_time"]
    stable_time = data[key]["stable_time"]

    ax = axes1[i]
    ax.plot(time, df_angle, color=color)
    ax.axvline(x=peak_time, color=color_peak, linestyle='--', label='Landing Peak')
    ax.axvline(x=stable_time, color=color_stable, linestyle='--', label='stable time')
    ax.set_title(key)
    ax.set_xlabel("Zeit (s)")
    if i == 0:
        ax.set_ylabel("Ankle Abduction (°)")
    ax.grid(True)
    ax.legend()

# Abstand optimieren
plt.tight_layout()
plt.suptitle(direktion + " Sprunggelenk - Abduction bei Pre-Rechts Messungen", fontsize=14, y=1.05)
plt.savefig("Plot_Bilder_IMU/sprunggelenk_Abducktion.png", dpi=300)
plt.show()


# Ankle Inversion
fig1, axes1 = plt.subplots(1, 3, figsize=(15, 4), sharey=True)

for i, (key, color) in enumerate(zip(keys_plotting, colors)):
    df = data[key]["df"]
    time = df["time"]
    df_angle = df[direktion + " Ankle Inversion (deg)"]
    peak_time = data[key]["landing_peak_time"]
    stable_time = data[key]["stable_time"]

    ax = axes1[i]
    ax.plot(time, df_angle, color=color)
    ax.axvline(x=peak_time, color=color_peak, linestyle='--', label='Landing Peak')
    ax.axvline(x=stable_time, color=color_stable, linestyle='--', label='stable time')
    ax.set_title(key)
    ax.set_xlabel("Zeit (s)")
    if i == 0:
        ax.set_ylabel("Ankle Inversion (°)")
    ax.grid(True)
    ax.legend()

# Abstand optimieren
plt.tight_layout()
plt.suptitle(direktion + " Sprunggelenk - Inversion bei Pre-Rechts Messungen", fontsize=14, y=1.05)
plt.show()

# %% [markdown]
# ## Variabilität des Sprunggelenks nach Stable Time --> für Inversion

# %%
# print (data["Re_1_Pre"]["df"][direktion + " Ankle Inversion (deg)"])

def calculate_std_post_stable(data, keys, RT_joint, LT_joint, window_seconds=3.0):
    """
    Berechnet die Standardabweichung des Sprunggelenks nach dem stabilen Zeitpunkt 
    und speichert sie als EINZELWERT in der Datenstruktur.

    """
    for key in keys:
        df = data[key]["df"]
        time = df["time"]
        stable_time = data[key]["stable_time"]

        # Gelenkwinkel je nach Seite wählen
        if key.startswith("Re"):
            joint = RT_joint
        elif key.startswith("Li"):
            joint = LT_joint


        if joint not in df.columns:
            std_value = np.nan
        else:
            # Signal nach stable_time im definierten Zeitfenster
            mask = (time >= stable_time) & (time <= stable_time + window_seconds)
            signal = df[joint][mask]
            std_value = np.std(signal)

        # Als einzelner Wert speichern
        data[key]["std von " + joint[3:]] = std_value       # als "std von Ankle Dorsiflexion (deg)"
        # return std_value


# joints = ["RT Ankle Dorsiflexion (deg)", "LT Ankle Dorsiflexion (deg)"]
RT_joint = "RT Ankle Inversion (deg)"
LT_joint = "LT Ankle Inversion (deg)"
# Funktion anwenden
std_value_Ankle_Inversion = calculate_std_post_stable(data, keys, RT_joint, LT_joint, window_seconds=3)

# Zugriff auf gespeicherte Werte
# print(data["Re_3_Pre"]["std von Ankle Inversion (deg)"])

### Printen der STD
last_phase = None  # Merken, ob vorher "Pre" oder "Post" war

for key in keys:
    # Teile Key auf → z. B. "Re_1_Pre" → ["Re", "1", "Pre"]
    parts = key.split("_")
    phase = parts[2]  # "Pre" oder "Post"

    # Trennlinie bei Wechsel von Pre → Post
    if last_phase is not None and phase != last_phase:
        print("--------------------------------------------------------------")

    std_value = data[key]["std von Ankle Inversion (deg)"]
    print(f"Standardabweichung für Ankle Dorsiflexion von {key}: {std_value:.3f}")

    last_phase = phase
# Out:
# Standardabweichung für Ankle Dorsiflexion von Li_1_Pre: 0.890
# Standardabweichung für Ankle Dorsiflexion von Li_2_Pre: 1.408
# Standardabweichung für Ankle Dorsiflexion von Li_3_Pre: 0.766
# Standardabweichung für Ankle Dorsiflexion von Re_1_Pre: 0.820
# Standardabweichung für Ankle Dorsiflexion von Re_2_Pre: 0.805
# Standardabweichung für Ankle Dorsiflexion von Re_3_Pre: 0.301
# --------------------------------------------------------------
# Standardabweichung für Ankle Dorsiflexion von Li_1_Post: 1.136
# Standardabweichung für Ankle Dorsiflexion von Li_2_Post: 1.602
# Standardabweichung für Ankle Dorsiflexion von Li_3_Post: 0.487
# Standardabweichung für Ankle Dorsiflexion von Re_1_Post: 0.431
# Standardabweichung für Ankle Dorsiflexion von Re_2_Post: 0.545
# Standardabweichung für Ankle Dorsiflexion von Re_3_Post: 0.392

# %% [markdown]
# ## Vergleiche

# %%
### plotten
plot_boxplot (
    title="Standartabweichung von Ankle Inversion: ",
    y_label="Standartabweichung",
    data_key="std von Ankle Inversion (deg)"
)

# %% [markdown]
# # Oberkörper Auswerten

# %%
### Plotten vom oberkörper

# direktion = "RT"
# direktion = "LT"
# keys_plotting = ["Re_1_Pre", "Re_2_Pre", "Re_3_Pre"]
# pre_li_keys = ["Li_1_Pre", "Li_2_Pre", "Li_3_Pre"]
# post_re_keys = ["Re_1_Post", "Re_2_Post", "Re_3_Post"]
# post_li_keys = ["Li_1_Post", "Li_2_Post", "Li_3_Post"]

keys_plotting, direktion = get_keys_and_direction("RT", "Pre")
# print (keys_plotting, direktion)

colors = ['blue', 'red', 'green']
color_peak = 'black'
color_stable = 'grey'



# Upper Spine Tilt lat
fig1, axes1 = plt.subplots(1, 3, figsize=(15, 4), sharey=True)

for i, (key, color) in enumerate(zip(keys_plotting, colors)):
    df = data[key]["df"]
    time = df["time"]
    df_angle = df["Noraxon MyoMotion-Segments-Upper spine-"+ direktion + " Tilt Lat (deg)"]

    peak_time = data[key]["landing_peak_time"]
    stable_time = data[key]["stable_time"]

    ax = axes1[i]
    ax.plot(time, df_angle, color=color)
    ax.axvline(x=peak_time, color=color_peak, linestyle='--', label='Landing Peak')
    ax.axvline(x=stable_time, color=color_stable, linestyle='--', label='stable time')
    ax.set_title(key)
    ax.set_xlabel("Zeit (s)")
    if i == 0:
        ax.set_ylabel(direktion + " tilt Lat (°)")
    ax.grid(True)
    ax.legend()

# Abstand optimieren
plt.tight_layout()
plt.suptitle(direktion + " Upper Spine - Tilt Lat", fontsize=14, y=1.05)
plt.savefig("Plot_Bilder_IMU/Upper_Spine_Tilt_lat.png", dpi=300)
plt.show()

# %%
### Daten in CSV speichern
# Erstelle DataFrame aus den Daten
# data_df = pd.DataFrame.from_dict(data, orient='index')
# Speichere DataFrame in CSV-Datei
# data_df.to_csv("C_Daten_Schröter_Till/C_Daten_Schröter_Till.csv", sep=';', decimal=',', encoding='utf-8')
